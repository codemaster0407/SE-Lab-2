# %% [markdown]
# ## Gradient Descent for n variables

# %%
import numpy as np
import pandas as pd

Boston = np.loadtxt("C:\\Users\\schai\\Downloads\\0000000000002417_training_boston_x_y_train.csv",delimiter = ",")

# %%
type(Boston)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7436/271137324.py in <module>
# ----> 1 type(Boston)
#
# NameError: name 'Boston' is not defined

# %%
print(Boston[0:13])
# Out:
# [[-4.07849910e-01 -4.87722360e-01 -1.26602310e+00 -2.72598570e-01
#   -5.76133940e-01  1.23997392e+00  8.40122020e-01 -5.20264280e-01
#   -7.52922150e-01 -1.27835435e+00 -3.03094150e-01  4.10571020e-01
#   -1.09799011e+00  3.79000000e+01]
#  [-4.07373680e-01 -4.87722360e-01  2.47056820e-01 -2.72598570e-01
#   -1.01668877e+00  1.94553000e-03 -8.38336970e-01  3.36350910e-01
#   -5.23001450e-01 -6.08013500e-02  1.13032100e-01  2.91169150e-01
#   -5.20474120e-01  2.14000000e+01]
#  [ 1.25178600e-01 -4.87722360e-01  1.01599907e+00 -2.72598570e-01
#    1.36749033e+00 -4.39698660e-01  6.87211570e-01 -5.77308570e-01
#    1.66124525e+00  1.53092646e+00  8.06575830e-01 -3.79579542e+00
#    8.91075880e-01  1.27000000e+01]
#  [ 2.83035900e-02 -4.87722360e-01  1.01599907e+00 -2.72598570e-01
#    1.85987514e+00 -4.79175200e-02  8.01005400e-01 -7.12836320e-01
#    1.66124525e+00  1.53092646e+00  8.06575830e-01 -6.60496400e-02
#    2.15438240e-01  1.99000000e+01]
# ...

# %%
df = pd.DataFrame(Boston)

# %%
df
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#            7         8         9         10        11        12    13
# ...

# %%
x_train = df.drop(13,axis = 1)

# %%
x_train
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#            7         8         9         10        11        12
# ...

# %%
y_train = df[13]

# %%
y_train
# Out:
# 0      37.9
# 1      21.4
# 2      12.7
# 3      19.9
# 4      22.5
#        ...
# 374    50.0
# 375    14.3
# 376    20.8
# 377    22.6
# 378    50.0
# Name: 13, Length: 379, dtype: float64

# %%
x_train.shape
# Out:
# (379, 13)

# %%
y_train.shape
# Out:
# (379,)

# %%
n_row = 14

# %%
len(x_train)
# Out:
# 379

# %%
print(x_train.loc[[0]])
print(y_train[0])
# Out:
#         0         1         2         3         4         5         6   \
# 0 -0.40785 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
#
#          7         8         9         10        11       12
# 0 -0.520264 -0.752922 -1.278354 -0.303094  0.410571 -1.09799
# 37.9

# %%
x_train = Boston[0:12]

# %%
len(x_train[0])
# Out:
# 14

# %%
print(Boston[0:12])
# Out:
# [[-4.07849910e-01 -4.87722360e-01 -1.26602310e+00 -2.72598570e-01
#   -5.76133940e-01  1.23997392e+00  8.40122020e-01 -5.20264280e-01
#   -7.52922150e-01 -1.27835435e+00 -3.03094150e-01  4.10571020e-01
#   -1.09799011e+00  3.79000000e+01]
#  [-4.07373680e-01 -4.87722360e-01  2.47056820e-01 -2.72598570e-01
#   -1.01668877e+00  1.94553000e-03 -8.38336970e-01  3.36350910e-01
#   -5.23001450e-01 -6.08013500e-02  1.13032100e-01  2.91169150e-01
#   -5.20474120e-01  2.14000000e+01]
#  [ 1.25178600e-01 -4.87722360e-01  1.01599907e+00 -2.72598570e-01
#    1.36749033e+00 -4.39698660e-01  6.87211570e-01 -5.77308570e-01
#    1.66124525e+00  1.53092646e+00  8.06575830e-01 -3.79579542e+00
#    8.91075880e-01  1.27000000e+01]
#  [ 2.83035900e-02 -4.87722360e-01  1.01599907e+00 -2.72598570e-01
#    1.85987514e+00 -4.79175200e-02  8.01005400e-01 -7.12836320e-01
#    1.66124525e+00  1.53092646e+00  8.06575830e-01 -6.60496400e-02
#    2.15438240e-01  1.99000000e+01]
# ...

# %%
len(x[0])
# Out:
# 14

# %%
def gradient(X,Y, m, j):
    M = len(X)
    N = len(X[0])
    
    m_slope = 0
    
    for i in range(M):
        m_tot = 0
        for k in range(N):
            m_tot += m[k]*X[i,k]
            
        m_slope = m_slope + (-2/M)*(Y[i] - m_tot )*X[i,j]
        
    return m_slope

def step_gradient(X, Y, learning_rate, m):

    M = len(X)           # 'M' datasaets
    N = len(X[0])        # 'N' features
    
    for j in range(N):
        Gradient = gradient(X , Y, m , j)
        m[j] = m[j] - learning_rate*Gradient
        
    return m

def cost(X, Y, m):
    tot_cost = 0
    M=len(X)
    N=len(X[0])
    for i in range(M):
        sum_mx = 0
        for k in range(len(m)):
            sum_mx= sum_mx+ m[k]*X[i][k]
        tot_cost = tot_cost+ (1/M)((Y[i]-sum_mx)*2)

    
    return tot_cost 

def GradientDescent(X, Y , learning_rate, num_iterations):
    # Starting with some random m and c
    m = np.zeros(len(X[0]))
    c = 0

    for i in range(num_iterations):
        m = step_gradient(X,Y, learning_rate, m)
        print(i+1, " Cost:", 10000*cost(X,Y, m))
        print()
    print("Final Cost :-", 10000*cost(X,Y,m))
    return m

def run(x_train, y_train):

    learning_rate = 0.9
    num_iterations = 6000
    m= GradientDescent(x_train, y_train,learning_rate, num_iterations)
    
    print(m)
    return m
