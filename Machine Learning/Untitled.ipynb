# %%
import pandas as pd

# %%
marks = pd.read_csv("C:\\Users\\schai\\Downloads\\DAA-MINOR-1-Marks-_1_.csv")

# %%
marks
# Out:
#      SERIAL NO Admission No Bracnch           Name of the Student  \
# 0            1  se20ucse001     CSE           A Teja Anvesh Yadav
# 1            2  se20ucse002     CSE                   Aaryan Nair
# 2            3  se20ucse003     CSE               Aashish Reddy T
# 3            4  se20ucse004     CSE                 Aayushi Singh
# 4            5  se20ucse005     CSE                    Abhi Rohan
# ..         ...          ...     ...                           ...
# 527        528  se20ucam040      CM  Venkat Nayan Reddy Mallagari
# 528        529  se20ucam041      CM              Gauransh Khurana
# 529        530  se20ucam042      CM                  Bhuvan Joshi
# 530        531  se20ucam044      CM                 Harshit Malik
# 531        532  se20ucam045      CM                 Ambati Sabdha
#
#      Minor 1 Marks  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0             46.0         NaN         NaN         NaN         NaN
# ...

# %%
count = 0
for i in marks["Minor 1 Marks"]:
    if i>50:
        count = count+1
        print(i)
print(count)
# Out:
# 56.0
# 54.0
# 52.0
# 55.0
# 51.0
# 55.0
# 51.0
# 52.0
# 8
