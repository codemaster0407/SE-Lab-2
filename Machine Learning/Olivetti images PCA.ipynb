# %%
from sklearn import datasets
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
oliv = datasets.fetch_olivetti_faces()

# %%
oliv.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
oliv['data'].shape
# Out:
# (400, 4096)

# %%
oliv['images'].shape

# 400 images which are the sample points 
#4096 features are all the pixel values
# Out:
# (400, 64, 64)

# %%
fig = plt.figure(figsize = (8,8))
for i in range(64):
    ax = fig.add_subplot(8,8, i+1)
    ax.imshow(oliv.images[i],cmap = plt.cm.bone)
plt.show()
#In each cell, we will have image
#8x8 = 64 images

# %%
pca = PCA()

x= oliv.data
y = oliv.target

pca.fit(x)
# Out:
# PCA()

# %%
print(x.shape)
print(y.shape)
# Out:
# (400, 4096)
# (400,)

# %%
pca.components_.shape
# Out:
# (400, 4096)

# %%
pca.explained_variance_.shape
# Out:
# (400,)

# %%
k = 0
total = sum(pca.explained_variance_)
currentsum = 0

while(currentsum/total<0.95):
    total += pca.explained_variance_[k]
    k = k+1
k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18708/3957720615.py in <module>
#       4 import numpy as np
#       5
# ----> 6 corr = x_train_pca.corr()
#       7
#       8 sns.heatmap(corr)
#
# NameError: name 'x_train_pca' is not defined
