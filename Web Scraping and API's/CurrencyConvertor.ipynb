# %% [markdown]
# Crawling -> Categorize web links
# Scraper -> Data extraction.

# %%
# url = "https://api.apilayer.com/exchangerates_data/latest"
# historical_url = url+ "/2016-01-26"
# payload = {}
# headers= {
#   "apikey": "A7OifYR86vdTwhZOeGHggNFty7ISa0wj"
# }

# response = requests.request("GET", url, headers=headers, data = payload)

# status_code = response.status_code
# result = response.text

# %%
# data = response.json()
# print(json.dumps(data, indent = 4))
# Out:
# {
#     "success": true,
#     "timestamp": 1669272423,
#     "base": "EUR",
#     "date": "2022-11-24",
#     "rates": {
#         "AED": 3.833018,
#         "AFN": 92.482704,
#         "ALL": 117.007545,
#         "AMD": 408.646247,
#         "ANG": 1.862169,
#         "AOA": 533.179323,
#         "ARS": 171.933613,
#         "AUD": 1.54415,
#         "AWG": 1.880975,
#         "AZN": 1.776804,
#         "BAM": 1.958141,
#         "BBD": 2.086152,
#         "BDT": 105.398704,
#         "BGN": 1.955212,
#         "BHD": 0.393403,
#         "BIF": 2138.754649,
#         "BMD": 1.043537,
#         "BND": 1.430589,
#         "BOB": 7.139527,
#         "BRL": 5.592836,
#         "BSD": 1.033215,
#         "BTC": 6.2519027e-05,
#         "BTN": 84.559517,
#         "BWP": 13.366505,
#         "BYN": 2.608967,
#         "BYR": 20453.31933,
#         "BZD": 2.082648,
#         "CAD": 1.392976,
#         "CDF": 2139.250625,
#         "CHF": 0.981143,
#         "CLF": 0.034659,
# ...

# %% [markdown]
# # Sending a GET request

# %%
import requests
import json

# %%
response = requests.get(base_url,headers)

# %% [markdown]
# # Investigating the response

# %%
response.ok
# Out:
# False

# %%
response.status_code
# Out:
# 401

# %%
response.text
# Out:
# '{\n  "error": {\n    "code": "invalid_access_key",\n    "message": "You have not supplied a valid API Access Key."\n  }\n}\n'

# %%
response.content
# Out:
# b'{\n  "error": {\n    "code": "invalid_access_key",\n    "message": "You have not supplied a valid API Access Key."\n  }\n}\n'

# %% [markdown]
# # Handling JSON

# %%
response.json()
# Out:
# {'success': False,
#  'error': {'code': 101,
#   'type': 'invalid_access_key',
#   'info': 'You have not supplied a valid API Access Key. [Technical Support: support@apilayer.com]'}}

# %%
param_url = base_url + "?sybmols = USD,GBP"
param_url
# Out:
# 'https://api.exchangeratesapi.io?sybmols = USD,GBP'

# %%
response = requests.get(param_url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [raw]
# Creating a currency converter.

# %%
url = "https://api.apilayer.com/exchangerates_data/latest"

# %%
headers= {
   "apikey": "A7OifYR86vdTwhZOeGHggNFty7ISa0wj"
}

base_url = url+"/"+date + "?base=" + base+ "&symbols=" + curr

# %%
response = requests.request("GET", url, headers = headers)

# %%
status = response.status_code

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1669282443,
#  'base': 'EUR',
#  'date': '2022-11-24',
#  'rates': {'AED': 3.826341,
#   'AFN': 92.323698,
#   'ALL': 116.806374,
#   'AMD': 407.943661,
#   'ANG': 1.858968,
#   'AOA': 532.262623,
#   'ARS': 171.642192,
#   'AUD': 1.544192,
#   'AWG': 1.877741,
#   'AZN': 1.77006,
#   'BAM': 1.954775,
#   'BBD': 2.082566,
#   'BDT': 105.217491,
#   'BGN': 1.956028,
#   'BHD': 0.392767,
#   'BIF': 2135.077485,
#   'BMD': 1.041743,
#   'BND': 1.428129,
#   'BOB': 7.127252,
#   'BRL': 5.583117,
#   'BSD': 1.031438,
#   'BTC': 6.2810883e-05,
#   'BTN': 84.414134,
#   'BWP': 13.343524,
#   'BYN': 2.604481,
#   'BYR': 20418.153911,
#   'BZD': 2.079067,
#   'CAD': 1.390596,
#   'CDF': 2135.572652,
#   'CHF': 0.982436,
#   'CLF': 0.034599,
#   'CLP': 954.705331,
#   'CNY': 7.431273,
#   'COP': 5087.203882,
#   'CRC': 625.973014,
#   'CUC': 1.041743,
#   'CUP': 27.606177,
#   'CVE': 110.205498,
#   'CZK': 24.365288,
#   'DJF': 183.619979,
# ...

# %%
curr_dict = response.json()

# %%
curr_dict.keys()
types_of_currency = list(curr_dict['rates'].keys())

# %%
types_of_currency
# Out:
# ['AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BIF',
#  'BMD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTC',
#  'BTN',
#  'BWP',
#  'BYN',
#  'BYR',
#  'BZD',
#  'CAD',
#  'CDF',
#  'CHF',
#  'CLF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CUC',
#  'CUP',
#  'CVE',
#  'CZK',
#  'DJF',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ERN',
#  'ETB',
#  'EUR',
#  'FJD',
#  'FKP',
#  'GBP',
#  'GEL',
#  'GGP',
#  'GHS',
#  'GIP',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HTG',
#  'HUF',
#  'IDR',
#  'ILS',
#  'IMP',
#  'INR',
#  'IQD',
#  'IRR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KMF',
#  'KPW',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'LTL',
#  'LVL',
#  'LYD',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MRO',
#  'MUR',
# ...

# %%
print("Enter the date of (in the format YYYY-MM-DD):")
date = input()
print("Convert from : ")
conv_f = input()
print("Convert to: ")
conv_t = input()

print("Enter the amount of "+conv_f+ "do you want to convert: ")
amount = int(input())

amount = curr_dict['rates'][conv_t] * amount

print(amount)
# Out:
# Enter the date of (in the format YYYY-MM-DD):
# 2009-07-03
# Convert from :
# GBP
# Convert to:
# USD
# Enter the amount of GBPdo you want to convert:
# 26
# 27.085318
